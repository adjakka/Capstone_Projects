# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
set_1 = pd.read_pickle('cloth_2.pkl')

# %%
set_2 = pd.read_pickle('cloth_1.pkl')

# %%
set_3 = pd.read_pickle('cloth_3.pkl')

# %%
set_4 = pd.read_pickle('cloth_35.pkl')

# %%
set_5 = pd.read_pickle('cloth_4.pkl')

# %%
full_set = pd.concat([set_1, set_2, set_3, set_4, set_5])

# %%
full_set = full_set.reset_index(drop=True)

# %%
full_set.head(2)
# Out:
#                                            Image_arr
# 0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1  [[[216, 176, 124], [216, 176, 124], [216, 176,...

# %%
plt.imshow(full_set['Image_arr'].loc[1947])

# %%
Images_np = full_set['Image_arr'].values

# %%
Images_np = np.stack(Images_np,axis = 0)

# %%
Images_np.shape
# Out:
# (41731, 224, 224, 3)

# %%
np.save('Images_np.npy', Images_np)

# %%
full_set['title'].to_csv('Clothing_titles.csv', header = ['title'])
